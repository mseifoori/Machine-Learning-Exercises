# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
fig = plt.figure()
ax = fig.add_subplot(211)

# %%
fig, ax = plt.subplots()

# %%
fig, axs = plt.subplots(2, 2, figsize=(6, 4))

# %%
x = np.linspace(0, 10, 100)
axs[0, 1].plot(x, np.sin(x))

fig

# %%
fig, axs = plt.subplots(2, 2, figsize=(6, 4))

# %%
np.random.seed(42)
a = np.random.rand(50)
b = a + np.random.rand(50)

axs[0, 0].set(
    xlim=(0, 1),
    ylim=(0, 2)
)
axs[0, 0].grid(True, linestyle='--', alpha=0.3, color='black')
axs[0, 0].scatter(a, b)

fig
